# %%
from pathlib import Path

root = Path.cwd()

print("Proyecto:")
print(root)

print("\nArchivos principales:")

for p in root.iterdir():
    print(p.name)
# Out:
# Proyecto:
# /Users/nachobreccia/Documents/STATSBOMB OPEN DATA/Proyecto Mundial
#
# Archivos principales:
# team_match_stats.csv
# 6_match_and_xi_master.ipynb
# assets.csv
# .DS_Store
# requirements.txt
# 12_streamlit_style_setup.ipynb
# team_similarity.csv
# 10_streamlit_pages_rebuild.ipynb
# player_master.csv
# 4_Player_Masters.ipynb
# matches.csv
# 1_Base Partidos.ipynb
# team_master.csv
# 7_assets_master.ipynb
# 99_Deploy_Streamlit.ipynb.ipynb
# 8_export_streamlit_data.ipynb
# README.md
# 3_team_master.ipynb
# .gitignore
# player_match_stats_with_positions.csv
# positions.csv
# events.csv
# most_frequent_xi.csv
# .ipynb_checkpoints
# 2_Bases Stats.ipynb
# 13_streamlit_full_layout.ipynb
# player_match_stats.csv
# 9_streamlit_rebuild.ipynb
# highlighted_matches.csv
# streamlit_app
# 5_Similarity_Model.ipynb
# 11_streamlit_visuals_rebuild.ipynb
# player_similarity.csv
# player_role_fit.csv

# %%
from pathlib import Path

home_files = list(Path(".").rglob("app.py"))

print(home_files)

if len(home_files) == 0:
    print("❌ No encontré Home.py")
else:
    print("✅ Home.py encontrado")
# Out:
# [PosixPath('streamlit_app/app.py')]
# ✅ Home.py encontrado

# %%
from pathlib import Path

pages = list(Path(".").rglob("pages/*.py"))

print(f"Cantidad de páginas: {len(pages)}\n")

for page in pages:
    print(page)
# Out:
# Cantidad de páginas: 6
#
# streamlit_app/pages/3_Team_Comparison.py
# streamlit_app/pages/4_Player_Tournament.py
# streamlit_app/pages/6_Player_Comparison.py
# streamlit_app/pages/1_Team_Tournament.py
# streamlit_app/pages/2_Team_Match.py
# streamlit_app/pages/5_Player_Match.py

# %%
requirements = """
streamlit
pandas
numpy
matplotlib
mplsoccer
plotly
scikit-learn
scipy
Pillow
"""

with open("requirements.txt", "w") as f:
    f.write(requirements.strip())

print("✅ requirements.txt creado")
# Out:
# ✅ requirements.txt creado

# %%
gitignore = """
__pycache__/
*.pyc
.ipynb_checkpoints/
.env
.DS_Store
"""

with open(".gitignore", "w") as f:
    f.write(gitignore.strip())

print("✅ .gitignore creado")
# Out:
# ✅ .gitignore creado

# %%
readme = """
# Football Analytics Dashboard

Interactive Football Analytics Dashboard powered by StatsBomb Open Data.

## Features

- Team Tournament Analysis
- Team Match Analysis
- Team Comparison
- Player Tournament Analysis
- Player Match Analysis
- Player Comparison
- Similar Teams
- Similar Players

## Tech Stack

- Streamlit
- Python
- Pandas
- NumPy
- Matplotlib
- mplsoccer
- StatsBomb Open Data

## Author

Juan Ignacio Breccia
"""

with open("README.md", "w", encoding="utf-8") as f:
    f.write(readme)

print("✅ README creado")
# Out:
# ✅ README creado

# %%
import os

os.system("streamlit run streamlit_app/app.py")
# Out:
# 2026-06-07 10:26:50.051 Uvicorn server started on 0.0.0.0:8501
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.86.125:8501
# /Users/nachobreccia/Documents/STATSBOMB OPEN DATA/Proyecto Mundial/streamlit_app/utils/data_loader.py:9: DtypeWarning: Columns (0,1,2,3,4,5,12,14,15,16,19,20,22,27,32,37,40,42,43,44,45,46,47,48,49,51,52,53,55,56,57,58,59,76,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(BASE_DIR / file_name)
# 2026-06-07 10:27:04.708 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-07 10:27:04.760 Please replace `use_container_width` with `width`.
#
# ...

# %%
# Out:
# streamlit_app/app.py
# streamlit_app/utils/style.py
# streamlit_app/utils/data_loader.py
# streamlit_app/utils/cards.py
# streamlit_app/utils/team_tournament_helpers.py
# streamlit_app/utils/visuals.py
# streamlit_app/utils/filters.py
# streamlit_app/pages/3_Team_Comparison.py
# streamlit_app/pages/4_Player_Tournament.py
# streamlit_app/pages/6_Player_Comparison.py
# streamlit_app/pages/1_Team_Tournament.py
# streamlit_app/pages/2_Team_Match.py
# streamlit_app/pages/5_Player_Match.py
